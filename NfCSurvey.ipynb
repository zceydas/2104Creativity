# %% [markdown]
# <a href="https://colab.research.google.com/github/zceydas/2104Creativity/blob/main/NfCSurvey.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
df <- read.csv("/Users/zsayali1/Documents/2104_Creativity/EBRWMC_Updated.csv")
# Out:
# Warning message in file(file, "rt"):
# “cannot open file '/Users/zsayali1/Documents/2104_Creativity/EBRWMC_Updated.csv': No such file or directory”
# Error in file(file, "rt"): cannot open the connection
# Traceback:
#
# 1. read.table(file = file, header = header, sep = sep, quote = quote,
#  .     dec = dec, fill = fill, comment.char = comment.char, ...)
# 2. file(file, "rt")
# 3. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "cannot open the connection", base::quote(file(file, "rt")))
